# %%
import requests
import pandas as pd
from env import api_key
from acquire import acquire
from datetime import timedelta, datetime

# %%
df = acquire()

# %%
df.tail(5)
# Out:
#             MSFT_price  AAPL_price  TSLA_price  SNDL_price  NIO_price  \
# date
# 2022-01-04      329.01      179.70     1149.59      0.6410      31.58
# 2022-01-05      316.38      174.92     1088.12      0.6120      29.88
# 2022-01-06      313.88      172.00     1064.70      0.5820      29.31
# 2022-01-07      314.04      172.17     1026.96      0.5960      29.30
# 2022-01-10      306.37      168.49     1010.57      0.5867      28.43
#
#             F_price  AMC_price  AMD_price  AMZN_price  DIS_price  ...  \
# date                                                              ...
# 2022-01-04   24.310      25.49    144.420     3350.44     155.73  ...
# 2022-01-05   23.660      22.75    136.150     3287.14     155.19  ...
# 2022-01-06   24.460      22.46    136.230     3265.08     156.90  ...
# 2022-01-07   24.440      22.99    132.000     3251.08     157.83  ...
# 2022-01-10   23.575      22.00    126.085     3156.14     155.59  ...
#
#             PENN_price  COST_price  ZM_price  IVR_price  INTC_price  \
# date
# 2022-01-04       49.77      564.23   179.850      2.980       53.14
# 2022-01-05       46.61      549.92   174.880      2.920       53.87
# 2022-01-06       46.86      549.80   176.330      2.930       54.01
# 2022-01-07       47.28      536.18   171.600      2.990       53.44
# 2022-01-10       45.71      509.59   167.495      2.886       54.13
#
#             NRZ_price  INO_price  FUBO_price  GSAT_price  TSM_price
# date
# 2022-01-04      10.98       5.02      15.810       1.160     133.40
# 2022-01-05      10.68       4.67      14.160       1.070     127.06
# 2022-01-06      10.77       4.65      13.920       1.060     128.47
# 2022-01-07      10.87       4.61      13.970       1.070     123.50
# 2022-01-10      10.86       4.71      13.019       1.055     124.01
#
# [5 rows x 100 columns]

# %%
# Need to reset index to change the date to a datetime64
df = df.reset_index()

# %%
# Converting type object to datetime64
df.date = pd.to_datetime(df.date)

# %%
df.tail(5)
# Out:
#            date  MSFT_price  AAPL_price  TSLA_price  SNDL_price  NIO_price  \
# 1255 2022-01-04      329.01      179.70     1149.59      0.6410      31.58
# 1256 2022-01-05      316.38      174.92     1088.12      0.6120      29.88
# 1257 2022-01-06      313.88      172.00     1064.70      0.5820      29.31
# 1258 2022-01-07      314.04      172.17     1026.96      0.5960      29.30
# 1259 2022-01-10      306.37      168.49     1010.57      0.5867      28.43
#
#       F_price  AMC_price  AMD_price  AMZN_price  ...  PENN_price  COST_price  \
# 1255   24.310      25.49    144.420     3350.44  ...       49.77      564.23
# 1256   23.660      22.75    136.150     3287.14  ...       46.61      549.92
# 1257   24.460      22.46    136.230     3265.08  ...       46.86      549.80
# 1258   24.440      22.99    132.000     3251.08  ...       47.28      536.18
# 1259   23.575      22.00    126.085     3156.14  ...       45.71      509.59
#
#       ZM_price  IVR_price  INTC_price  NRZ_price  INO_price  FUBO_price  \
# 1255   179.850      2.980       53.14      10.98       5.02      15.810
# 1256   174.880      2.920       53.87      10.68       4.67      14.160
# 1257   176.330      2.930       54.01      10.77       4.65      13.920
# 1258   171.600      2.990       53.44      10.87       4.61      13.970
# 1259   167.495      2.886       54.13      10.86       4.71      13.019
#
#       GSAT_price  TSM_price
# 1255       1.160     133.40
# 1256       1.070     127.06
# 1257       1.060     128.47
# 1258       1.070     123.50
# 1259       1.055     124.01
#
# [5 rows x 101 columns]

# %%
# Making the index equal to the sale_date
df = df.set_index('date').sort_index()

# %%
df.tail(5)
# Out:
#             MSFT_price  AAPL_price  TSLA_price  SNDL_price  NIO_price  \
# date
# 2022-01-04      329.01      179.70     1149.59      0.6410      31.58
# 2022-01-05      316.38      174.92     1088.12      0.6120      29.88
# 2022-01-06      313.88      172.00     1064.70      0.5820      29.31
# 2022-01-07      314.04      172.17     1026.96      0.5960      29.30
# 2022-01-10      306.37      168.49     1010.57      0.5867      28.43
#
#             F_price  AMC_price  AMD_price  AMZN_price  DIS_price  ...  \
# date                                                              ...
# 2022-01-04   24.310      25.49    144.420     3350.44     155.73  ...
# 2022-01-05   23.660      22.75    136.150     3287.14     155.19  ...
# 2022-01-06   24.460      22.46    136.230     3265.08     156.90  ...
# 2022-01-07   24.440      22.99    132.000     3251.08     157.83  ...
# 2022-01-10   23.575      22.00    126.085     3156.14     155.59  ...
#
#             PENN_price  COST_price  ZM_price  IVR_price  INTC_price  \
# date
# 2022-01-04       49.77      564.23   179.850      2.980       53.14
# 2022-01-05       46.61      549.92   174.880      2.920       53.87
# 2022-01-06       46.86      549.80   176.330      2.930       54.01
# 2022-01-07       47.28      536.18   171.600      2.990       53.44
# 2022-01-10       45.71      509.59   167.495      2.886       54.13
#
#             NRZ_price  INO_price  FUBO_price  GSAT_price  TSM_price
# date
# 2022-01-04      10.98       5.02      15.810       1.160     133.40
# 2022-01-05      10.68       4.67      14.160       1.070     127.06
# 2022-01-06      10.77       4.65      13.920       1.060     128.47
# 2022-01-07      10.87       4.61      13.970       1.070     123.50
# 2022-01-10      10.86       4.71      13.019       1.055     124.01
#
# [5 rows x 100 columns]

# %%
df.MSFT_price.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ### Going to create columns that check the price of the previous closing day

# %%
series = df.MSFT_price

# %%
new_df = pd.DataFrame(series)

# %%
new_df['difference'] = new_df.resample('1D').mean().diff(1)

# %%
new_df
# Out:
#             MSFT_price  difference
# date
# 2017-01-10       62.62         NaN
# 2017-01-11       63.19        0.57
# 2017-01-12       62.61       -0.58
# 2017-01-13       62.70        0.09
# 2017-01-17       62.53         NaN
# ...                ...         ...
# 2022-01-04      329.01       -5.74
# 2022-01-05      316.38      -12.63
# 2022-01-06      313.88       -2.50
# 2022-01-07      314.04        0.16
# 2022-01-10      306.37         NaN
#
# [1260 rows x 2 columns]

# %%
new_df.iloc[1].MSFT_price - new_df.iloc[0].MSFT_price
# Out:
# 0.5700000000000003
