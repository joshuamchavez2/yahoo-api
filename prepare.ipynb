# %%
import requests
import pandas as pd
from env import api_key
from acquire import acquire
from datetime import timedelta, datetime

# %%
df = acquire()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1260 entries, 2017-01-10 to 2022-01-10
# Data columns (total 100 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MSFT_price   1260 non-null   float64
#  1   AAPL_price   1260 non-null   float64
#  2   TSLA_price   1259 non-null   float64
#  3   SNDL_price   615 non-null    float64
#  4   NIO_price    836 non-null    float64
#  5   F_price      1253 non-null   float64
#  6   AMC_price    1254 non-null   float64
#  7   AMD_price    1259 non-null   float64
#  8   AMZN_price   1260 non-null   float64
#  9   DIS_price    1260 non-null   float64
#  10  NFLX_price   1260 non-null   float64
#  11  LCID_price   324 non-null    float64
#  12  NVDA_price   1260 non-null   float64
#  13  GPRO_price   1256 non-null   float64
#  14  PLUG_price   1239 non-null   float64
#  15  SNAP_price   1223 non-null   float64
#  16  FB_price     1260 non-null   float64
# ...

# %%
df.tail(5)
# Out:
#             MSFT_price  AAPL_price  TSLA_price  SNDL_price  NIO_price  \
# date
# 2022-01-04      329.01      179.70     1149.59      0.6410      31.58
# 2022-01-05      316.38      174.92     1088.12      0.6120      29.88
# 2022-01-06      313.88      172.00     1064.70      0.5820      29.31
# 2022-01-07      314.04      172.17     1026.96      0.5960      29.30
# 2022-01-10      306.37      168.49     1010.57      0.5867      28.43
#
#             F_price  AMC_price  AMD_price  AMZN_price  DIS_price  ...  \
# date                                                              ...
# 2022-01-04   24.310      25.49    144.420     3350.44     155.73  ...
# 2022-01-05   23.660      22.75    136.150     3287.14     155.19  ...
# 2022-01-06   24.460      22.46    136.230     3265.08     156.90  ...
# 2022-01-07   24.440      22.99    132.000     3251.08     157.83  ...
# 2022-01-10   23.575      22.00    126.085     3156.14     155.59  ...
#
# ...
